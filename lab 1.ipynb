# %% [markdown]
# # кутеж на Титанике

# %%
import pandas as pd
import re

# %%
data = pd.read_csv('titanic.csv', index_col='PassengerId')

# %%
# вопрос 1 (сколько было мужчин и женщин)
women_count = data[data['Sex'] == 'female'].shape[0]
men_count = data[data['Sex'] == 'male'].shape[0]

print( women_count, men_count)
# Out:
# 314 577

# %%
# скольким удалось выжить ?

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
survivors = data[data['Survived'] == 1].shape[0]
all_pass = data.shape[0]
print("{:.2f}".format((survivors/all_dudes)*100))
# Out:
# 38.38

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
first_class = data[data['Pclass'] == 1].shape[0]
print("{:.2f}".format((first_class/all_dudes)*100))
# Out:
# 24.24

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mean = data['Age'].mean()
median = data['Age'].median()

# %%
print(mean, median)
# Out:
# 29.69911764705882 28.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
SibSpNum = data['SibSp']
ParchNum = data['Parch']
print(ParchNum.corr(SibSpNum, method='pearson'))
# Out:
# 0.41483769862015696

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fem = data.loc[data['Sex']=='female', 'Name']

first= fem.str.extract(r"Mrs\.\s+[^(]*\((\w+)", expand=False)
first.loc[first.isna()] = fem.str.extract(r"\.\s+(\w+)", expand=False)

# %%
first.value_counts()
# Out:
# Name
# Anna         15
# Mary         14
# Elizabeth    11
# Margaret     10
# Alice         7
#              ..
# Miriam        1
# Helmina       1
# Laura         1
# Nora          1
# Gerda         1
# Name: count, Length: 177, dtype: int64
